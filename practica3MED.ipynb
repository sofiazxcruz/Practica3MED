# %%
#EJERCICIO PRACTICO 
lista = []

def menu():
    print("A) Agregar un número a la lista")
    print("B) Agregar un número a la lista según la posición")
    print("C) Ver longitud de la lista")
    print("D) Eliminar el último número")
    print("E) Eliminar un número")
    print("F) Contar repeticiones de un número")
    print("G) Salir")

def seleccionarOpcion(opcion):
    print("\n")
    opcion = opcion.upper()

    if opcion == "A":
        numero = int(input("Ingresa un número: "))
        lista.append(numero)
    elif opcion == "B":
        posicion = int(input("Ingresa la posición: "))
        numero = int(input("Ingresa el número: "))
        lista.insert(posicion, numero)
    elif opcion == "C":
        print("La longitud de la lista es de {0}".format(len(lista)))
    elif opcion == "D":
        if len(lista) > 0:
            numero = lista.pop()
            print("Se borró el número {0}".format(numero))
        else:
            print("La lista está vacía, no se puede eliminar ningún número.")
    elif opcion == "E":
        if len(lista) > 0:
            print("De la lista, ¿qué número desea borrar?", lista)
            numero = int(input("Ingresa el número a borrar: "))
            if numero in lista:
                lista.remove(numero)
                print("Se borró {0}".format(numero))
            else:
                print("El número no está en la lista.")
        else:
            print("La lista está vacía, no se puede borrar ningún número.")
    elif opcion == "F":
        numero = int(input("Ingresa el número que se desea contar: "))
        total = lista.count(numero)
        print("En la lista, el número {0} se repite {1} veces.".format(numero, total))
    elif opcion == "G":
        print("Gracias por usar nuestro programa")
    else:
        print("Esta opción no es válida :()")

while True:
    menu()

    opcion = input("Ingresa una opción A-G: ")
    seleccionarOpcion(opcion)

    if opcion.upper() == "G":
        break

# %%
#EJERCICIO 1
meses = (
    "Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio",
    "Julio", "Agosto", "Septiembre", "Octubre", "Noviembre", "Diciembre"
)

numero = int(input("Ingrese un número entre 1 y 12: "))

if 1 <= numero <= 12:
    mes = meses[numero - 1]  
    print(f"El número {numero} corresponde al mes de {mes}.")
else:
    print("Número fuera del rango válido. Por favor, ingrese un número entre 1 y 12.")

# %%
# EJERCICIO 2
cadena = input("Ingresa una cadena: ")

lista_palabras = cadena.split()

cantidad_palabras = len(lista_palabras)

print("La cadena tiene {0} palabras.".format(cantidad_palabras))

# %%
#EJERCICIO 3 
notas = []
for i in range(5):
    while True:
        try:
            nota = float(input("Ingresa la nota {0} (entre 0 y 10): ".format(i + 1)))
            if 0 <= nota <= 10:
                notas.append(nota)
                break
            else:
                print("La nota debe estar entre 0 y 10. Intenta nuevamente.")
        except ValueError:
            print("Por favor, ingresa un valor numérico.")

print("Las notas obtenidas son:")
for i, nota in enumerate(notas):
    print("Nota {0}: {1}".format(i + 1, nota))

nota_media = sum(notas) / len(notas)
print("La nota media es: {0:.2f}".format(nota_media))

nota_maxima = max(notas)
nota_minima = min(notas)
print("La nota más alta es: {0}".format(nota_maxima))
print("La nota menor es: {0}".format(nota_minima))
